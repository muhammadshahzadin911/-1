# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadshahzadin911/-1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
w=np.array([1,23,4])

for i in w:
  print(i)
# Out:
# 1
# 23
# 4

# %%
import seaborn as sns
df=sns.load_dataset('iris')

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
x=df[['sepal_width','petal_length']].values[0].reshape(2,1)
x
# Out:
# array([[3.5],
#        [1.4]])
